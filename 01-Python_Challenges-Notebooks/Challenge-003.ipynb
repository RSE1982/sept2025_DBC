# %% [markdown]
# <img src="../_images/logos/Python.png" width="200">

# %% [markdown]
# # Integers, Floats & Decimals Challenge

# %% [markdown]
# ## Steps

# %% [markdown]
# 1. Declare a variable named **num1** and assign it a value of **77**
# 2. Declare a variable named **num2** and assign it a value of **3.15**

# %% [markdown]
# ## My Solution

# %%
# Declare your variables here
num1 = 77
num2 = 3.15

# These will print the value TYPES to the terminal 
print(type(num1))
print(type(num2))
# Out:
# <class 'int'>
# <class 'float'>
