# %% [markdown]
# <img src="../_images/logos/Python.png" width="200">

# %% [markdown]
# # Declaring Variables in Python Challenge

# %% [markdown]
# ## Steps

# %% [markdown]
# 1. Declare a variable named **num** and assign it a value of **42**
# 2. On the second line do: **print(num)**
# 3. Declare a variable named: **temporary_password** and assign it a value of **True**
# 4. On the next line do: **print(temporary_password)**

# %% [markdown]
# ## My Solution

# %%
num = 42
print(num)
temporary_password = True
print(temporary_password)
# Out:
# 42
# True
