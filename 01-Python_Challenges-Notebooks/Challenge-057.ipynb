# %% [markdown]
# # Third Party Libraries Challenge

# %% [markdown]
# ## Steps

# %% [markdown]
# 1. At the top of the python file, **import** the **parser** function from the **dateutil** module

# %% [markdown]
# ## My Solution

# %%
from dateutil import parser
log_line = 'INFO 2020-07-03T23:27:51 Shutdown complete.'

timestamp = parser.parse(log_line, fuzzy=True)
print(timestamp)
# Out:
# 2020-07-03 23:27:51
