# %% [markdown]
# <img src="../_images/logos/Python.png" width="200">

# %% [markdown]
# # The import Statement Challenge

# %% [markdown]
# ## Steps

# %% [markdown]
# 1. Use what you have learned in the previous lesson to import the functions in the helpers.py file into the main.py file.

# %% [markdown]
# ## My Solution

# %%
import imports.helpers as helpers
list_integers = [1, 2, 3, 4, 5]

addition = helpers.add_integers(list_integers)
print(addition)

multiplication = helpers.multiply_intergers(list_integers)
print(multiplication)
# Out:
# 15
# 120
