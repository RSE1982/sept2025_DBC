# %% [markdown]
# # Truthy & Falsy Values Challenge

# %%
a = None
b = None
c = None
d = None
e = None

print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
print(bool(e))
# Out:
# False
# False
# False
# False
# False

# %% [markdown]
# ## Steps

# %% [markdown]
# - Assign a value, which should be a list, to the variable a so that when it is checked for a truthy falsy value, it is False (Look to the text at top of this page to see how lists are created in Python)
# - Assign a value, which should be a string, to the variable b so that when it is checked for a truthy falsy value, it is False
# - Assign a value, which should be a string, to the variable c so that when it is checked for a truthy falsy value, it is True
# - Assign a value, which should be a float, to the variable d so that when it is checked for a truthy falsy value, it is False
# - Assign a value, which should be an int, to the variable e so that when it is checked for a truthy falsy value, it is True

# %% [markdown]
# ## My Solution

# %%
a = []
b = ""
c = "True"
d = 0.0
e = 1

print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
print(bool(e))
# Out:
# False
# False
# True
# False
# True
