# %% [markdown]
# # Ternary Expressions in Python Challenge

# %% [markdown]
# ## Steps

# %% [markdown]
# 1. Assign a ternary conditional statement to the variable result, that evaluates to True if the variable full_access is True or False otherwise

# %% [markdown]
# ## My Solution

# %%
full_access = True
result = True if full_access else False

print(result)
# Out:
# True
