# %% [markdown]
# # Basic Math With Arithmetic Operators Challenge

# %% [markdown]
# ## Steps

# %% [markdown]
# 1. Create a variable product and assign it a value: $72$
# 2. Create a variable total_cost and assign it an arithmetic expression: $product + product * 0.21$, using the variable product and the value 0.21 to calculate the cost of the product after vat is applied to it.
# 3. Finally to see the value assigned to total_cost do: print(total_cost)

# %% [markdown]
# ## My Solution

# %%
product = 72
total_cost = product + product * 0.21
print(total_cost)
# Out:
# 87.12
