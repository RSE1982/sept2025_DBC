# %% [markdown]
# # Determining the Data Type Challenge

# %% [markdown]
# ## Steps

# %% [markdown]
# using print()
# 1. print the type of the variable itm_one
# 2. print the type of the variable itm_two
# 3. print the type of the variable itm_three
# 4. print the type of the variable itm_four

# %% [markdown]
# ## My Solution

# %%
itm_one = 10
itm_two = 21.56
itm_three = 'A string of text'
itm_four = True

# %%
print(type(itm_one))
print(type(itm_two))
print(type(itm_three))
print(type(itm_four))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
