# %% [markdown]
# <img src="../_images/logos/Python.png" width="200">

# %% [markdown]
# # Converting Between Data Types Challenge

# %% [markdown]
# ## Steps

# %% [markdown]
# 1. Use a data conversion method to convert "2.2" into a number type, so that the result printed to the terminal is 42.2
# 2. Use a data conversion method to convert 42 into a string, so that the result printed to the terminal is The answer to the ultimate question is 42

# %% [markdown]
# ## My Solution

# %%
result = 40 + float("2.2")
print(result)

result_two = "The answer to the ultimate question is " + str(42)
print(result_two)
# Out:
# 42.2
# The answer to the ultimate question is 42
