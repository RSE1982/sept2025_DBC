# %% [markdown]
# # Comparing Values With Comparison Operators Challenge

# %% [markdown]
# ## Steps

# %% [markdown]
# Using print()
# 1. print whether a is equal to b
# 2. print whether a is less than b
# 3. print whether a is less than or equal to b
# 4. print whether a is greater than b
# 5. print whether a is greater than or equal to b

# %%
a = 10
b = 5

# %% [markdown]
# ## My Solution

# %%
print(a == b)
print(a < b)
print(a <= b)
print(a > b)
print(a >= b)
# Out:
# False
# False
# False
# True
# True
