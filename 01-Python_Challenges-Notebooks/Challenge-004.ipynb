# %% [markdown]
# ## None Challenge

# %% [markdown]
# ## Steps

# %% [markdown]
# 1. Create a variable named admin, assign it the value: None
# 2. On the next line type: print(admin)

# %% [markdown]
# ## My Solution

# %%
admin = None
print(admin)
# Out:
# None
