# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('tips')

# %%
#df["tip"].mean()

#df[['tip','total_bill']].corr()

#df[df["tip"] > 5]

# %%
df[(df['tip'] / df['total_bill']) > 0.2]

df['tip_pct'] = df['tip'] / df['total_bill']
df['good_tip'] = df['tip_pct'] > 0.2
df.value_counts('good_tip')

# %%
df.groupby('day').tip.mean()
# Out:
# /tmp/ipykernel_114730/3364099143.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('day').tip.mean()
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
df.groupby('day')['tip'].mean()
# Out:
# /tmp/ipykernel_114730/4148581069.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('day')['tip'].mean()
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
df.sort_values('tip', ascending=False).head(7)
# Out:
#      total_bill    tip     sex smoker   day    time  size   tip_pct  good_tip
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  0.196812     False
# 212       48.33   9.00    Male     No   Sat  Dinner     4  0.186220     False
# 23        39.42   7.58    Male     No   Sat  Dinner     4  0.192288     False
# 59        48.27   6.73    Male     No   Sat  Dinner     4  0.139424     False
# 141       34.30   6.70    Male     No  Thur   Lunch     6  0.195335     False
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4  0.280535      True
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3  0.230742      True
